# %%
import pandas as pd 
import numpy as np



df = pd.read_csv('player_mvp_stats.csv')

# %%
df = df.drop(axis=1,columns='Unnamed: 0')

# %%
df
# Out:
#                     Player  Pos   Age   Tm     G    GS    MP   FG   FGA  \
# 0               A.C. Green   PF  22.0  LAL  82.0   1.0  18.8  2.5   4.7
# 1              Byron Scott   SG  24.0  LAL  76.0  62.0  28.8  6.7  13.0
# 2             James Worthy   SF  24.0  LAL  75.0  73.0  32.7  8.4  14.5
# 3         Jerome Henderson    C  26.0  LAL   1.0   0.0   3.0  2.0   3.0
# 4      Kareem Abdul-Jabbar    C  38.0  LAL  79.0  79.0  33.3  9.6  16.9
# ...                    ...  ...   ...  ...   ...   ...   ...  ...   ...
# 19119                  NaN  NaN   NaN  NaN   NaN   NaN   NaN  NaN   NaN
# 19120                  NaN  NaN   NaN  NaN   NaN   NaN   NaN  NaN   NaN
# 19121                  NaN  NaN   NaN  NaN   NaN   NaN   NaN  NaN   NaN
# 19122                  NaN  NaN   NaN  NaN   NaN   NaN   NaN  NaN   NaN
# 19123                  NaN  NaN   NaN  NaN   NaN   NaN   NaN  NaN   NaN
#
#          FG%  ...  Pts Max  Share                Team     W     L   W/L%  \
# 0      0.539  ...      0.0  0.000  Los Angeles Lakers  62.0  20.0  0.756
# 1      0.513  ...      0.0  0.000  Los Angeles Lakers  62.0  20.0  0.756
# 2      0.579  ...    780.0  0.009  Los Angeles Lakers  62.0  20.0  0.756
# 3      0.667  ...      0.0  0.000  Los Angeles Lakers  62.0  20.0  0.756
# 4      0.564  ...    780.0  0.173  Los Angeles Lakers  62.0  20.0  0.756
# ...      ...  ...      ...    ...                 ...   ...   ...    ...
# 19119    NaN  ...      NaN    NaN   Kansas City Kings  45.0  37.0  0.549
# 19120    NaN  ...      NaN    NaN  San Diego Clippers  25.0  57.0  0.305
# 19121    NaN  ...      NaN    NaN   Kansas City Kings  38.0  44.0  0.463
# 19122    NaN  ...      NaN    NaN  San Diego Clippers  30.0  52.0  0.366
# 19123    NaN  ...      NaN    NaN   Kansas City Kings  31.0  51.0  0.378
#
#          GB   PS/G   PA/G   SRS
# 0       0.0  117.3  109.5  6.84
# 1       0.0  117.3  109.5  6.84
# 2       0.0  117.3  109.5  6.84
# 3       0.0  117.3  109.5  6.84
# 4       0.0  117.3  109.5  6.84
# ...     ...    ...    ...   ...
# 19119   8.0  113.8  112.3  1.04
# 19120  33.0  108.6  113.4 -4.61
# 19121   7.0  110.0  111.5 -1.62
# 19122  24.0  110.7  114.0 -3.21
# 19123  21.0  114.8  117.5 -2.71
#
# [19124 rows x 41 columns]

# %%
df.dtypes
# Out:
# Player      object
# Pos         object
# Age        float64
# Tm          object
# G          float64
# GS         float64
# MP         float64
# FG         float64
# FGA        float64
# FG%        float64
# 3P         float64
# 3PA        float64
# 3P%        float64
# 2P         float64
# 2PA        float64
# 2P%        float64
# eFG%       float64
# FT         float64
# FTA        float64
# FT%        float64
# ORB        float64
# DRB        float64
# TRB        float64
# AST        float64
# STL        float64
# BLK        float64
# TOV        float64
# PF         float64
# PTS        float64
# Year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# Team        object
# W          float64
# L          float64
# W/L%       float64
# GB         float64
# PS/G       float64
# PA/G       float64
# SRS        float64
# dtype: object

# %%
highest_scoring = df[df["G"] > 20].sort_values("PTS", ascending=False).head(10)

highest_scoring.plot.bar("Player", "PTS")
# Out:
# <Axes: xlabel='Player'>

# %%
highest_blocking = df[df["G"] > 20].sort_values("BLK", ascending=False).head(10)

highest_blocking.plot.bar("Player", "BLK")
# Out:
# <Axes: xlabel='Player'>

# %%
highest_stealing = df[df["G"] > 20].sort_values("STL", ascending=False).head(10)

highest_stealing.plot.bar("Player", "STL")
# Out:
# <Axes: xlabel='Player'>

# %%
highest_scoring_by_year = df.groupby("Year").apply(lambda x: x.sort_values("PTS", ascending=False).head(1))

# %%
type(highest_scoring_by_year)
# Out:
# pandas.core.frame.DataFrame

# %%
highest_scoring_by_year.plot.bar("Year", "PTS")
# Out:
# <Axes: xlabel='Year'>

# %%
highest_scoring_by_team = df.groupby("Team").apply(lambda x: x.sort_values("PTS", ascending=False).head(1))

# %%
highest_scoring_by_team.plot.bar("Team", "PTS")
# Out:
# <Axes: xlabel='Team'>

# %%
highest_scoring_by_age = df.groupby("Age").apply(lambda x: x.sort_values("PTS", ascending=False).head(1))

# %%
highest_scoring_by_age.plot.bar("Age", "PTS")
# Out:
# <Axes: xlabel='Age'>

# %%
highest_scoring_by_position = df.groupby("Pos").apply(lambda x: x.sort_values("PTS", ascending=False).head(1))

# %%
highest_scoring_by_position.plot.bar("Pos", "PTS")
# Out:
# <Axes: xlabel='Pos'>

# %%
average_scoring_by_position = df.groupby("Pos").mean()
# Out:
# C:\Users\ruwin\AppData\Local\Temp\ipykernel_21288\2687903373.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   average_scoring_by_position = df.groupby("Pos").mean()

# %%
average_scoring_by_position['PTS'].plot.bar()
# Out:
# <Axes: xlabel='Pos'>

# %%
average_scoring_by_position['TRB'].plot.bar()
# Out:
# <Axes: xlabel='Pos'>

# %%
average_scoring_by_year = df.groupby("Year").mean()
# Out:
# C:\Users\ruwin\AppData\Local\Temp\ipykernel_21288\2118644952.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   average_scoring_by_year = df.groupby("Year").mean()

# %%
average_scoring_by_year['PTS'].sort_values(ascending=False).plot.bar()
# Out:
# <Axes: xlabel='Year'>

# %%
average_scoring_by_team = df.groupby("Team").mean()
# Out:
# C:\Users\ruwin\AppData\Local\Temp\ipykernel_21288\961689865.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   average_scoring_by_team = df.groupby("Team").mean()

# %%
average_scoring_by_team['PTS'].sort_values(ascending=False).plot.bar()
# Out:
# <Axes: xlabel='Team'>

# %%
average_scoring_by_team['W'].sort_values(ascending=False).plot.bar()
# Out:
# <Axes: xlabel='Team'>
